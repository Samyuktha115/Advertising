# %%
import pandas as pd
df=pd.read_csv('/content/advertising.csv')
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
import seaborn as sns
sns.regplot(x='TV',y='Sales',data=df)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
import seaborn as sns
sns.regplot(x='Radio',y='Sales',data=df)
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
import seaborn as sns
sns.regplot(x='Newspaper',y='Sales',data=df)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
X=df.iloc[:,:-1]
X
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
mlr=LinearRegression()
mlr.fit(X_train,y_train)
y_pred=mlr.predict(X_test)
y_pred
# Out:
# array([21.28816103, 18.04213212, 10.0595901 , 21.08224067, 20.76476044,
#        24.47187353, 16.80643646, 15.62885738, 10.12479884, 18.84601896,
#        15.78389695, 10.54297035, 18.92928707, 15.52557996, 17.8412711 ,
#        15.24120343, 13.74212833, 21.0643733 , 10.05392699, 19.26500889,
#        11.16451173, 11.97211832,  8.61179009, 11.98972141, 12.59914023,
#        16.8447954 ,  9.7170889 , 21.09489946, 18.13942474, 19.55008709,
#        22.08796224, 17.78527998, 16.53883452, 14.77303861, 21.39458945,
#        16.95491635, 17.22755002, 12.31866943, 21.04982199,  7.77473926,
#         5.38467516,  9.63139004,  6.89549204, 19.19507436,  7.88125192,
#        15.18766673, 13.70978421, 21.0232936 , 20.5350058 , 20.48867548,
#        24.86087902, 14.96304281,  7.33545571, 19.35630325, 21.32554066,
#        14.7719757 , 17.19642519,  7.11988693, 18.30096543,  9.65158222])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
import numpy as np
print("r2_score:",r2_score(y_test,y_pred))
print("mean absolute error:",mean_absolute_error(y_test,y_pred))
print("mean squared error:",mean_squared_error(y_test,y_pred))
print("RMSE:",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2_score: 0.9071151423684273
# mean absolute error: 1.194741713405674
# mean squared error: 2.370659971225658
# RMSE: 1.5396947656031237

# %%
print(mlr.coef_)
# Out:
# [ 0.05502392  0.10251003 -0.00150711]

# %%
print(mlr.intercept_)
# Out:
# 4.661439720130817

# %%
#y=C+m1*x1+m2*x2+m3*x3
4.661439720130817+0.05502392*210.8+0.10251003*49.6+-0.00150711*370.7
# Out:
# 20.78629386713082

# %%
X_test
# Out:
#         TV  Radio  Newspaper
# 58   210.8   49.6       37.7
# 40   202.5   22.3       31.6
# 34    95.7    1.4        7.4
# 102  280.2   10.1       21.4
# 184  253.8   21.3       30.0
# 198  283.6   42.0       66.2
# 95   163.3   31.6       52.9
# 4    180.8   10.8       58.4
# 29    70.6   16.0       40.8
# 168  215.4   23.6       57.6
# 171  164.5   20.9       47.4
# 18    69.2   20.5       18.3
# 11   214.7   24.0        4.0
# 89   109.8   47.8       51.4
# 110  225.8    8.2       56.5
# 118  125.7   36.9       79.2
# 159  131.7   18.4       34.6
# 35   290.7    4.1        8.5
# 136   25.6   39.0        9.3
# 59   210.7   29.5        9.3
# 51   100.4    9.6        3.6
# 16    67.8   36.6      114.0
# 44    25.1   25.7       43.3
# 94   107.4   14.0       10.9
# 31   112.9   17.4       38.6
# 162  188.4   18.1       25.6
# 38    43.1   26.7       35.1
# 28   248.8   27.1       22.9
# 193  166.8   42.0        3.6
# 27   240.1   16.7       22.9
# 47   239.9   41.5       18.5
# ...

# %%
from sklearn.svm import SVR
sv=SVR()
sv.fit(X_train,y_train)
y_pred_sv=sv.predict(X_test)
y_pred_sv
# Out:
# array([19.96787776, 18.21141927, 11.52596852, 19.74323574, 20.03311084,
#        21.33783715, 16.91137506, 16.72161108, 10.64313425, 19.07584436,
#        16.35517558, 10.7450902 , 18.41900528, 14.69470348, 18.63022265,
#        15.27891076, 14.3293148 , 19.26210535,  9.33090844, 18.63449289,
#        12.148702  , 12.68520345,  8.63465586, 12.69455041, 13.2258525 ,
#        17.22629221,  9.49787777, 20.08745132, 17.16758765, 19.29524756,
#        20.39926849, 18.67337343, 16.03936018, 15.81152562, 20.17715391,
#        17.17765645, 17.7387891 , 13.52274225, 19.85548227,  8.24765131,
#         7.51872851, 11.11471511,  7.92687554, 18.99366299,  8.07900017,
#        15.38662665, 12.59433526, 20.07721039, 19.300897  , 20.03110903,
#        21.35816774, 14.61488827,  8.06594232, 18.64423546, 19.61006061,
#        15.55714816, 17.8931818 ,  8.0998118 , 18.32862076,  9.48617263])

# %%
print("r2_score:",r2_score(y_test,y_pred_sv))
print("mean absolute error:",mean_absolute_error(y_test,y_pred_sv))
print("mean squared error:",mean_squared_error(y_test,y_pred_sv))
print("RMSE:",np.sqrt(mean_squared_error(y_test,y_pred_sv)))
# Out:
# r2_score: 0.8784996204503526
# mean absolute error: 1.39669180347963
# mean squared error: 3.10100153708118
# RMSE: 1.7609660806163132
